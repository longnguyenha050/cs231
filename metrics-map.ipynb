# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_HOG_Flat.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính và in Precision@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_and_print_precision_at_k(ground_truth, test_submission):
    for k in range(1, 11):  # Tính Precision từ 1 đến 10
        print(f"Precision@{k}:")
        for idx, row in test_submission.iterrows():
            query_id = row['id']
            predicted_images = row['images']
            
            # Tìm ảnh liên quan trong ground truth
            relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
            if len(relevant_images) == 0:
                print(f"Query {query_id}: Precision@{k} = 0.0")  # Nếu không có ground truth, Precision = 0
                continue
            relevant_images = relevant_images[0]
            
            # Tính Precision@k cho truy vấn này
            precision = calculate_precision_at_k(relevant_images, predicted_images, k)
            print(f"Query {query_id}: Precision@{k} = {precision:.4f}")
        print("")  # Dòng trống giữa các k

# Tính và in Precision@k cho tất cả các k từ 1 đến 10
calculate_and_print_precision_at_k(ground_truth, test_submission)
# Out:
# Precision@1:
# Query MEN/Tees_Tanks/id_00000100/01_2_side.jpg: Precision@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00000904/03_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Dresses/id_00001761/01_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00005319/01_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Blouses_Shirts/id_00001233/03_4_full.jpg: Precision@1 = 0.0000
# Query WOMEN/Graphic_Tees/id_00002129/01_2_side.jpg: Precision@1 = 0.0000
# Query WOMEN/Blouses_Shirts/id_00001823/02_3_back.jpg: Precision@1 = 1.0000
# Query WOMEN/Tees_Tanks/id_00006247/03_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Leggings/id_00002674/01_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Leggings/id_00002463/03_2_side.jpg: Precision@1 = 0.0000
# Query WOMEN/Blouses_Shirts/id_00007544/05_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Cardigans/id_00001273/04_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Dresses/id_00005988/04_1_front.jpg: Precision@1 = 0.0000
# ...

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_HOG_IVF.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính và in Precision@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_and_print_precision_at_k(ground_truth, test_submission):
    for k in range(1, 11):  # Tính Precision từ 1 đến 10
        print(f"Precision@{k}:")
        for idx, row in test_submission.iterrows():
            query_id = row['id']
            predicted_images = row['images']
            
            # Tìm ảnh liên quan trong ground truth
            relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
            if len(relevant_images) == 0:
                print(f"Query {query_id}: Precision@{k} = 0.0")  # Nếu không có ground truth, Precision = 0
                continue
            relevant_images = relevant_images[0]
            
            # Tính Precision@k cho truy vấn này
            precision = calculate_precision_at_k(relevant_images, predicted_images, k)
            print(f"Query {query_id}: Precision@{k} = {precision:.4f}")
        print("")  # Dòng trống giữa các k

# Tính và in Precision@k cho tất cả các k từ 1 đến 10
calculate_and_print_precision_at_k(ground_truth, test_submission)
# Out:
# Precision@1:
# Query WOMEN/Shorts/id_00004192/01_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Dresses/id_00000547/01_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Dresses/id_00004954/02_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Graphic_Tees/id_00006273/01_3_back.jpg: Precision@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00003828/03_2_side.jpg: Precision@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00006196/03_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Dresses/id_00002536/03_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Jackets_Coats/id_00004877/03_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Dresses/id_00003331/02_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Skirts/id_00004895/01_2_side.jpg: Precision@1 = 0.0000
# Query WOMEN/Sweatshirts_Hoodies/id_00006629/01_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00006541/01_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00007758/03_1_front.jpg: Precision@1 = 0.0000
# ...

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_Resnet152_Flat.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính và in Precision@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_and_print_precision_at_k(ground_truth, test_submission):
    for k in range(1, 11):  # Tính Precision từ 1 đến 10
        print(f"Precision@{k}:")
        for idx, row in test_submission.iterrows():
            query_id = row['id']
            predicted_images = row['images']
            
            # Tìm ảnh liên quan trong ground truth
            relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
            if len(relevant_images) == 0:
                print(f"Query {query_id}: Precision@{k} = 0.0")  # Nếu không có ground truth, Precision = 0
                continue
            relevant_images = relevant_images[0]
            
            # Tính Precision@k cho truy vấn này
            precision = calculate_precision_at_k(relevant_images, predicted_images, k)
            print(f"Query {query_id}: Precision@{k} = {precision:.4f}")
        print("")  # Dòng trống giữa các k

# Tính và in Precision@k cho tất cả các k từ 1 đến 10
calculate_and_print_precision_at_k(ground_truth, test_submission)
# Out:
# Precision@1:
# Query WOMEN/Sweaters/id_00004836/02_2_side.jpg: Precision@1 = 1.0000
# Query WOMEN/Shorts/id_00006514/01_2_side.jpg: Precision@1 = 0.0000
# Query WOMEN/Jackets_Coats/id_00006174/01_3_back.jpg: Precision@1 = 1.0000
# Query WOMEN/Tees_Tanks/id_00004619/01_1_front.jpg: Precision@1 = 1.0000
# Query MEN/Denim/id_00002476/01_3_back.jpg: Precision@1 = 1.0000
# Query WOMEN/Tees_Tanks/id_00002824/03_1_front.jpg: Precision@1 = 1.0000
# Query WOMEN/Rompers_Jumpsuits/id_00006906/02_2_side.jpg: Precision@1 = 1.0000
# Query WOMEN/Graphic_Tees/id_00004233/01_1_front.jpg: Precision@1 = 1.0000
# Query WOMEN/Shorts/id_00006281/01_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Pants/id_00005566/02_1_front.jpg: Precision@1 = 1.0000
# Query WOMEN/Blouses_Shirts/id_00005387/01_3_back.jpg: Precision@1 = 1.0000
# Query WOMEN/Tees_Tanks/id_00002738/01_3_back.jpg: Precision@1 = 1.0000
# Query WOMEN/Rompers_Jumpsuits/id_00006217/03_1_front.jpg: Precision@1 = 1.0000
# ...

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_Resnet152_IVF.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính và in Precision@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_and_print_precision_at_k(ground_truth, test_submission):
    for k in range(1, 11):  # Tính Precision từ 1 đến 10
        print(f"Precision@{k}:")
        for idx, row in test_submission.iterrows():
            query_id = row['id']
            predicted_images = row['images']
            
            # Tìm ảnh liên quan trong ground truth
            relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
            if len(relevant_images) == 0:
                print(f"Query {query_id}: Precision@{k} = 0.0")  # Nếu không có ground truth, Precision = 0
                continue
            relevant_images = relevant_images[0]
            
            # Tính Precision@k cho truy vấn này
            precision = calculate_precision_at_k(relevant_images, predicted_images, k)
            print(f"Query {query_id}: Precision@{k} = {precision:.4f}")
        print("")  # Dòng trống giữa các k

# Tính và in Precision@k cho tất cả các k từ 1 đến 10
calculate_and_print_precision_at_k(ground_truth, test_submission)
# Out:
# Precision@1:
# Query WOMEN/Blouses_Shirts/id_00002330/03_1_front.jpg: Precision@1 = 1.0000
# Query WOMEN/Rompers_Jumpsuits/id_00001038/03_1_front.jpg: Precision@1 = 1.0000
# Query WOMEN/Dresses/id_00002562/03_2_side.jpg: Precision@1 = 1.0000
# Query WOMEN/Blouses_Shirts/id_00001325/02_2_side.jpg: Precision@1 = 1.0000
# Query WOMEN/Dresses/id_00005964/01_4_full.jpg: Precision@1 = 1.0000
# Query WOMEN/Dresses/id_00003833/02_7_additional.jpg: Precision@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00007925/01_1_front.jpg: Precision@1 = 0.0000
# Query WOMEN/Sweaters/id_00000464/02_7_additional.jpg: Precision@1 = 1.0000
# Query WOMEN/Blouses_Shirts/id_00002078/03_7_additional.jpg: Precision@1 = 0.0000
# Query WOMEN/Dresses/id_00000229/02_2_side.jpg: Precision@1 = 0.0000
# Query WOMEN/Dresses/id_00007270/04_1_front.jpg: Precision@1 = 1.0000
# Query WOMEN/Jackets_Coats/id_00000054/01_2_side.jpg: Precision@1 = 1.0000
# Query WOMEN/Shorts/id_00005752/02_2_side.jpg: Precision@1 = 1.0000
# ...

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_HOG_Flat.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính AP cho một truy vấn
def calculate_ap_for_query(relevant_images, predicted_images, k):
    precision_sum = 0.0
    relevant_count = 0

    # Duyệt qua top k ảnh và tính Precision cho các ảnh liên quan
    for i in range(min(k, len(predicted_images))):
        if predicted_images[i] in relevant_images:
            relevant_count += 1
            precision_sum += relevant_count / (i + 1)
    
    # Tính AP cho truy vấn này
    if relevant_count > 0:
        ap = precision_sum / relevant_count
    else:
        ap = 0.0
    return ap

# Hàm tính và in AP@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_and_print_ap_at_k(ground_truth, test_submission):
    for k in range(1, 11):  # Tính AP từ 1 đến 10
        print(f"AP@{k}:")
        for idx, row in test_submission.iterrows():
            query_id = row['id']
            predicted_images = row['images']
            
            # Tìm ảnh liên quan trong ground truth
            relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
            if len(relevant_images) == 0:
                print(f"Query {query_id}: AP@{k} = 0.0")  # Nếu không có ground truth, AP = 0
                continue
            relevant_images = relevant_images[0]
            
            # Tính AP cho truy vấn này
            ap = calculate_ap_for_query(relevant_images, predicted_images, k)
            print(f"Query {query_id}: AP@{k} = {ap:.4f}")
        print("")  # Dòng trống giữa các k

# Tính và in AP@k cho tất cả các k từ 1 đến 10
calculate_and_print_ap_at_k(ground_truth, test_submission)
# Out:
# AP@1:
# Query MEN/Tees_Tanks/id_00000100/01_2_side.jpg: AP@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00000904/03_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Dresses/id_00001761/01_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00005319/01_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Blouses_Shirts/id_00001233/03_4_full.jpg: AP@1 = 0.0000
# Query WOMEN/Graphic_Tees/id_00002129/01_2_side.jpg: AP@1 = 0.0000
# Query WOMEN/Blouses_Shirts/id_00001823/02_3_back.jpg: AP@1 = 1.0000
# Query WOMEN/Tees_Tanks/id_00006247/03_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Leggings/id_00002674/01_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Leggings/id_00002463/03_2_side.jpg: AP@1 = 0.0000
# Query WOMEN/Blouses_Shirts/id_00007544/05_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Cardigans/id_00001273/04_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Dresses/id_00005988/04_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Dresses/id_00003121/02_2_side.jpg: AP@1 = 0.0000
# Query WOMEN/Pants/id_00003334/01_2_side.jpg: AP@1 = 0.0000
# ...

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_HOG_IVF.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính AP cho một truy vấn
def calculate_ap_for_query(relevant_images, predicted_images, k):
    precision_sum = 0.0
    relevant_count = 0

    # Duyệt qua top k ảnh và tính Precision cho các ảnh liên quan
    for i in range(min(k, len(predicted_images))):
        if predicted_images[i] in relevant_images:
            relevant_count += 1
            precision_sum += relevant_count / (i + 1)
    
    # Tính AP cho truy vấn này
    if relevant_count > 0:
        ap = precision_sum / relevant_count
    else:
        ap = 0.0
    return ap

# Hàm tính và in AP@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_and_print_ap_at_k(ground_truth, test_submission):
    for k in range(1, 11):  # Tính AP từ 1 đến 10
        print(f"AP@{k}:")
        for idx, row in test_submission.iterrows():
            query_id = row['id']
            predicted_images = row['images']
            
            # Tìm ảnh liên quan trong ground truth
            relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
            if len(relevant_images) == 0:
                print(f"Query {query_id}: AP@{k} = 0.0")  # Nếu không có ground truth, AP = 0
                continue
            relevant_images = relevant_images[0]
            
            # Tính AP cho truy vấn này
            ap = calculate_ap_for_query(relevant_images, predicted_images, k)
            print(f"Query {query_id}: AP@{k} = {ap:.4f}")
        print("")  # Dòng trống giữa các k

# Tính và in AP@k cho tất cả các k từ 1 đến 10
calculate_and_print_ap_at_k(ground_truth, test_submission)
# Out:
# AP@1:
# Query WOMEN/Shorts/id_00004192/01_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Dresses/id_00000547/01_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Dresses/id_00004954/02_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Graphic_Tees/id_00006273/01_3_back.jpg: AP@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00003828/03_2_side.jpg: AP@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00006196/03_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Dresses/id_00002536/03_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Jackets_Coats/id_00004877/03_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Dresses/id_00003331/02_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Skirts/id_00004895/01_2_side.jpg: AP@1 = 0.0000
# Query WOMEN/Sweatshirts_Hoodies/id_00006629/01_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00006541/01_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00007758/03_1_front.jpg: AP@1 = 0.0000
# Query MEN/Tees_Tanks/id_00000568/01_2_side.jpg: AP@1 = 0.0000
# Query WOMEN/Shorts/id_00004441/02_2_side.jpg: AP@1 = 0.0000
# ...

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_Resnet152_Flat.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính AP cho một truy vấn
def calculate_ap_for_query(relevant_images, predicted_images, k):
    precision_sum = 0.0
    relevant_count = 0

    # Duyệt qua top k ảnh và tính Precision cho các ảnh liên quan
    for i in range(min(k, len(predicted_images))):
        if predicted_images[i] in relevant_images:
            relevant_count += 1
            precision_sum += relevant_count / (i + 1)
    
    # Tính AP cho truy vấn này
    if relevant_count > 0:
        ap = precision_sum / relevant_count
    else:
        ap = 0.0
    return ap

# Hàm tính và in AP@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_and_print_ap_at_k(ground_truth, test_submission):
    for k in range(1, 11):  # Tính AP từ 1 đến 10
        print(f"AP@{k}:")
        for idx, row in test_submission.iterrows():
            query_id = row['id']
            predicted_images = row['images']
            
            # Tìm ảnh liên quan trong ground truth
            relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
            if len(relevant_images) == 0:
                print(f"Query {query_id}: AP@{k} = 0.0")  # Nếu không có ground truth, AP = 0
                continue
            relevant_images = relevant_images[0]
            
            # Tính AP cho truy vấn này
            ap = calculate_ap_for_query(relevant_images, predicted_images, k)
            print(f"Query {query_id}: AP@{k} = {ap:.4f}")
        print("")  # Dòng trống giữa các k

# Tính và in AP@k cho tất cả các k từ 1 đến 10
calculate_and_print_ap_at_k(ground_truth, test_submission)
# Out:
# AP@1:
# Query WOMEN/Sweaters/id_00004836/02_2_side.jpg: AP@1 = 1.0000
# Query WOMEN/Shorts/id_00006514/01_2_side.jpg: AP@1 = 0.0000
# Query WOMEN/Jackets_Coats/id_00006174/01_3_back.jpg: AP@1 = 1.0000
# Query WOMEN/Tees_Tanks/id_00004619/01_1_front.jpg: AP@1 = 1.0000
# Query MEN/Denim/id_00002476/01_3_back.jpg: AP@1 = 1.0000
# Query WOMEN/Tees_Tanks/id_00002824/03_1_front.jpg: AP@1 = 1.0000
# Query WOMEN/Rompers_Jumpsuits/id_00006906/02_2_side.jpg: AP@1 = 1.0000
# Query WOMEN/Graphic_Tees/id_00004233/01_1_front.jpg: AP@1 = 1.0000
# Query WOMEN/Shorts/id_00006281/01_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Pants/id_00005566/02_1_front.jpg: AP@1 = 1.0000
# Query WOMEN/Blouses_Shirts/id_00005387/01_3_back.jpg: AP@1 = 1.0000
# Query WOMEN/Tees_Tanks/id_00002738/01_3_back.jpg: AP@1 = 1.0000
# Query WOMEN/Rompers_Jumpsuits/id_00006217/03_1_front.jpg: AP@1 = 1.0000
# Query WOMEN/Tees_Tanks/id_00007274/01_3_back.jpg: AP@1 = 1.0000
# ...

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_Resnet152_IVF.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính AP cho một truy vấn
def calculate_ap_for_query(relevant_images, predicted_images, k):
    precision_sum = 0.0
    relevant_count = 0

    # Duyệt qua top k ảnh và tính Precision cho các ảnh liên quan
    for i in range(min(k, len(predicted_images))):
        if predicted_images[i] in relevant_images:
            relevant_count += 1
            precision_sum += relevant_count / (i + 1)
    
    # Tính AP cho truy vấn này
    if relevant_count > 0:
        ap = precision_sum / relevant_count
    else:
        ap = 0.0
    return ap

# Hàm tính và in AP@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_and_print_ap_at_k(ground_truth, test_submission):
    for k in range(1, 11):  # Tính AP từ 1 đến 10
        print(f"AP@{k}:")
        for idx, row in test_submission.iterrows():
            query_id = row['id']
            predicted_images = row['images']
            
            # Tìm ảnh liên quan trong ground truth
            relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
            if len(relevant_images) == 0:
                print(f"Query {query_id}: AP@{k} = 0.0")  # Nếu không có ground truth, AP = 0
                continue
            relevant_images = relevant_images[0]
            
            # Tính AP cho truy vấn này
            ap = calculate_ap_for_query(relevant_images, predicted_images, k)
            print(f"Query {query_id}: AP@{k} = {ap:.4f}")
        print("")  # Dòng trống giữa các k

# Tính và in AP@k cho tất cả các k từ 1 đến 10
calculate_and_print_ap_at_k(ground_truth, test_submission)
def calculate_map_at_k(ground_truth, test_submission, k):
    ap_list = []
    for idx, row in test_submission.iterrows():
        query_id = row['id']
        predicted_images = row['images']
        
        # Lấy ảnh liên quan từ ground truth
        relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
        if len(relevant_images) == 0:
            continue  # Nếu không có ảnh liên quan, bỏ qua truy vấn này
        relevant_images = relevant_images[0]
        
        # Tính AP@k cho truy vấn này
        ap_at_k = calculate_ap_at_k(relevant_images, predicted_images, k)
        ap_list.append(ap_at_k)
    
    # Tính mAP@k
    map_at_k = sum(ap_list) / len(ap_list) if ap_list else 0.0
    return map_at_k

# Tính mAP cho top 1, top 5, top 10
map_at_1 = calculate_map_at_k(ground_truth, test_submission, 1)
map_at_5 = calculate_map_at_k(ground_truth, test_submission, 5)
map_at_10 = calculate_map_at_k(ground_truth, test_submission, 10)

print(f"mAP@1: {map_at_1:.4f}")
print(f"mAP@5: {map_at_5:.4f}")
print(f"mAP@10: {map_at_10:.4f}")
# Out:
# AP@1:
# Query WOMEN/Blouses_Shirts/id_00002330/03_1_front.jpg: AP@1 = 1.0000
# Query WOMEN/Rompers_Jumpsuits/id_00001038/03_1_front.jpg: AP@1 = 1.0000
# Query WOMEN/Dresses/id_00002562/03_2_side.jpg: AP@1 = 1.0000
# Query WOMEN/Blouses_Shirts/id_00001325/02_2_side.jpg: AP@1 = 1.0000
# Query WOMEN/Dresses/id_00005964/01_4_full.jpg: AP@1 = 1.0000
# Query WOMEN/Dresses/id_00003833/02_7_additional.jpg: AP@1 = 0.0000
# Query WOMEN/Tees_Tanks/id_00007925/01_1_front.jpg: AP@1 = 0.0000
# Query WOMEN/Sweaters/id_00000464/02_7_additional.jpg: AP@1 = 1.0000
# Query WOMEN/Blouses_Shirts/id_00002078/03_7_additional.jpg: AP@1 = 0.0000
# Query WOMEN/Dresses/id_00000229/02_2_side.jpg: AP@1 = 0.0000
# Query WOMEN/Dresses/id_00007270/04_1_front.jpg: AP@1 = 1.0000
# Query WOMEN/Jackets_Coats/id_00000054/01_2_side.jpg: AP@1 = 1.0000
# Query WOMEN/Shorts/id_00005752/02_2_side.jpg: AP@1 = 1.0000
# Query WOMEN/Sweaters/id_00001210/03_4_full.jpg: AP@1 = 0.0000
# ...

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_Resnet152_IVF.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính AP cho một truy vấn
def calculate_ap_for_query(relevant_images, predicted_images, k):
    precision_sum = 0.0
    relevant_count = 0

    # Duyệt qua top k ảnh và tính Precision cho các ảnh liên quan
    for i in range(min(k, len(predicted_images))):
        if predicted_images[i] in relevant_images:
            relevant_count += 1
            precision_sum += relevant_count / (i + 1)
    
    # Tính AP cho truy vấn này
    if relevant_count > 0:
        ap = precision_sum / relevant_count
    else:
        ap = 0.0
    return ap

# Hàm tính mAP@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_map_at_k(ground_truth, test_submission, k):
    ap_list = []
    
    # Duyệt qua tất cả các truy vấn trong test_submission
    for idx, row in test_submission.iterrows():
        query_id = row['id']
        predicted_images = row['images']
        
        # Lấy ảnh liên quan từ ground truth
        relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
        if len(relevant_images) == 0:
            continue  # Nếu không có ảnh liên quan trong ground truth, bỏ qua truy vấn này
        relevant_images = relevant_images[0]
        
        # Tính AP@k cho truy vấn này
        ap_at_k = calculate_ap_for_query(relevant_images, predicted_images, k)
        ap_list.append(ap_at_k)
    
    # Tính mAP@k
    map_at_k = sum(ap_list) / len(ap_list) if ap_list else 0.0
    return map_at_k

# Tính mAP cho top 1, top 5, top 10
map_at_1 = calculate_map_at_k(ground_truth, test_submission, 1)
map_at_5 = calculate_map_at_k(ground_truth, test_submission, 5)
map_at_10 = calculate_map_at_k(ground_truth, test_submission, 10)

print(f"mAP@1: {map_at_1:.4f}")
print(f"mAP@5: {map_at_5:.4f}")
print(f"mAP@10: {map_at_10:.4f}")
# Out:
# mAP@1: 0.7400
# mAP@5: 0.7535
# mAP@10: 0.7410

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_Resnet152_Flat.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính AP cho một truy vấn
def calculate_ap_for_query(relevant_images, predicted_images, k):
    precision_sum = 0.0
    relevant_count = 0

    # Duyệt qua top k ảnh và tính Precision cho các ảnh liên quan
    for i in range(min(k, len(predicted_images))):
        if predicted_images[i] in relevant_images:
            relevant_count += 1
            precision_sum += relevant_count / (i + 1)
    
    # Tính AP cho truy vấn này
    if relevant_count > 0:
        ap = precision_sum / relevant_count
    else:
        ap = 0.0
    return ap

# Hàm tính mAP@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_map_at_k(ground_truth, test_submission, k):
    ap_list = []
    
    # Duyệt qua tất cả các truy vấn trong test_submission
    for idx, row in test_submission.iterrows():
        query_id = row['id']
        predicted_images = row['images']
        
        # Lấy ảnh liên quan từ ground truth
        relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
        if len(relevant_images) == 0:
            continue  # Nếu không có ảnh liên quan trong ground truth, bỏ qua truy vấn này
        relevant_images = relevant_images[0]
        
        # Tính AP@k cho truy vấn này
        ap_at_k = calculate_ap_for_query(relevant_images, predicted_images, k)
        ap_list.append(ap_at_k)
    
    # Tính mAP@k
    map_at_k = sum(ap_list) / len(ap_list) if ap_list else 0.0
    return map_at_k

# Tính mAP cho top 1, top 5, top 10
map_at_1 = calculate_map_at_k(ground_truth, test_submission, 1)
map_at_5 = calculate_map_at_k(ground_truth, test_submission, 5)
map_at_10 = calculate_map_at_k(ground_truth, test_submission, 10)

print(f"mAP@1: {map_at_1:.4f}")
print(f"mAP@5: {map_at_5:.4f}")
print(f"mAP@10: {map_at_10:.4f}")
# Out:
# mAP@1: 0.9000
# mAP@5: 0.8869
# mAP@10: 0.8581

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_HOG_IVF.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính AP cho một truy vấn
def calculate_ap_for_query(relevant_images, predicted_images, k):
    precision_sum = 0.0
    relevant_count = 0

    # Duyệt qua top k ảnh và tính Precision cho các ảnh liên quan
    for i in range(min(k, len(predicted_images))):
        if predicted_images[i] in relevant_images:
            relevant_count += 1
            precision_sum += relevant_count / (i + 1)
    
    # Tính AP cho truy vấn này
    if relevant_count > 0:
        ap = precision_sum / relevant_count
    else:
        ap = 0.0
    return ap

# Hàm tính mAP@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_map_at_k(ground_truth, test_submission, k):
    ap_list = []
    
    # Duyệt qua tất cả các truy vấn trong test_submission
    for idx, row in test_submission.iterrows():
        query_id = row['id']
        predicted_images = row['images']
        
        # Lấy ảnh liên quan từ ground truth
        relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
        if len(relevant_images) == 0:
            continue  # Nếu không có ảnh liên quan trong ground truth, bỏ qua truy vấn này
        relevant_images = relevant_images[0]
        
        # Tính AP@k cho truy vấn này
        ap_at_k = calculate_ap_for_query(relevant_images, predicted_images, k)
        ap_list.append(ap_at_k)
    
    # Tính mAP@k
    map_at_k = sum(ap_list) / len(ap_list) if ap_list else 0.0
    return map_at_k

# Tính mAP cho top 1, top 5, top 10
map_at_1 = calculate_map_at_k(ground_truth, test_submission, 1)
map_at_5 = calculate_map_at_k(ground_truth, test_submission, 5)
map_at_10 = calculate_map_at_k(ground_truth, test_submission, 10)

print(f"mAP@1: {map_at_1:.4f}")
print(f"mAP@5: {map_at_5:.4f}")
print(f"mAP@10: {map_at_10:.4f}")
# Out:
# mAP@1: 0.0300
# mAP@5: 0.0450
# mAP@10: 0.0504

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (thay đường dẫn bằng file cụ thể của bạn)
ground_truth = pd.read_csv('/kaggle/input/deepfashion1/ground_truth.csv')
test_submission = pd.read_csv('/kaggle/input/deepfashion1/test_submission_HOG_Flat.csv')

# Chuyển các giá trị 'relevant_images' và 'images' thành danh sách
ground_truth['relevant_images'] = ground_truth['relevant_images'].apply(lambda x: set(x.split()) if isinstance(x, str) else set())
test_submission['images'] = test_submission['images'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Hàm tính Precision@k cho một truy vấn
def calculate_precision_at_k(relevant_images, predicted_images, k):
    # Lấy top k ảnh dự đoán
    top_k_predicted = predicted_images[:k]
    
    # Tính số lượng ảnh đúng trong top k
    relevant_in_top_k = len(set(top_k_predicted) & relevant_images)
    
    # Tính Precision tại vị trí k
    precision_at_k = relevant_in_top_k / k
    return precision_at_k

# Hàm tính AP cho một truy vấn
def calculate_ap_for_query(relevant_images, predicted_images, k):
    precision_sum = 0.0
    relevant_count = 0

    # Duyệt qua top k ảnh và tính Precision cho các ảnh liên quan
    for i in range(min(k, len(predicted_images))):
        if predicted_images[i] in relevant_images:
            relevant_count += 1
            precision_sum += relevant_count / (i + 1)
    
    # Tính AP cho truy vấn này
    if relevant_count > 0:
        ap = precision_sum / relevant_count
    else:
        ap = 0.0
    return ap

# Hàm tính mAP@k cho tất cả các truy vấn từ k = 1 đến 10
def calculate_map_at_k(ground_truth, test_submission, k):
    ap_list = []
    
    # Duyệt qua tất cả các truy vấn trong test_submission
    for idx, row in test_submission.iterrows():
        query_id = row['id']
        predicted_images = row['images']
        
        # Lấy ảnh liên quan từ ground truth
        relevant_images = ground_truth[ground_truth['query'] == query_id]['relevant_images'].values
        if len(relevant_images) == 0:
            continue  # Nếu không có ảnh liên quan trong ground truth, bỏ qua truy vấn này
        relevant_images = relevant_images[0]
        
        # Tính AP@k cho truy vấn này
        ap_at_k = calculate_ap_for_query(relevant_images, predicted_images, k)
        ap_list.append(ap_at_k)
    
    # Tính mAP@k
    map_at_k = sum(ap_list) / len(ap_list) if ap_list else 0.0
    return map_at_k

# Tính mAP cho top 1, top 5, top 10
map_at_1 = calculate_map_at_k(ground_truth, test_submission, 1)
map_at_5 = calculate_map_at_k(ground_truth, test_submission, 5)
map_at_10 = calculate_map_at_k(ground_truth, test_submission, 10)

print(f"mAP@1: {map_at_1:.4f}")
print(f"mAP@5: {map_at_5:.4f}")
print(f"mAP@10: {map_at_10:.4f}")
# Out:
# mAP@1: 0.1200
# mAP@5: 0.1498
# mAP@10: 0.1547

# %%
import matplotlib.pyplot as plt
import numpy as np

# Giả sử bạn có các giá trị mAP@1, mAP@5, mAP@10 cho các phương pháp
methods = ['ResNet152 flat', 'ResNet152 IVF', 'HOG flat', 'HOG IVF']
map_at_1 = [0.9, 0.74, 0.12, 0.03]  # Các giá trị mAP@1
map_at_5 = [0.89, 0.75, 0.15, 0.045]  # Các giá trị mAP@5
map_at_10 = [0.86, 0.74, 0.155, 0.05]  # Các giá trị mAP@10

# Tạo một biểu đồ dạng cột nhóm
bar_width = 0.2  # Chiều rộng của mỗi cột
index = np.arange(len(methods))  # Vị trí của các nhóm

# Vẽ các cột cho từng giá trị k (1, 5, 10)
plt.figure(figsize=(10, 6))
plt.bar(index - bar_width, map_at_1, bar_width, label='mAP@1', color='b')
plt.bar(index, map_at_5, bar_width, label='mAP@5', color='g')
plt.bar(index + bar_width, map_at_10, bar_width, label='mAP@10', color='r')

# Thêm nhãn và tiêu đề
plt.xlabel('Methods')
plt.ylabel('mAP')
plt.title('Comparison of mAP at k = 1, 5, 10 for Different Feature Extraction Methods')
plt.xticks(index, methods, rotation=45)
plt.legend()

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()
